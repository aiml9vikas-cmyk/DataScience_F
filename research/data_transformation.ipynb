# %%
import os

# %%
# %pwd
# Out:
# 'f:\\AIml_project\\DataScience_F\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'f:\\AIml_project\\DataScience_F'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTranformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath= CONFIG_FILE_PATH,
        params_filepath= PARAMS_FILE_PATH,
        schema_filepath= SCHEMA_FILE_PATH):
        
        self.config= read_yaml(config_filepath)
        self.params= read_yaml(params_filepath)
        self.schema= read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTranformationConfig:
        config=self.config.data_transformation
        create_directories([config.root_dir])

        data_transformation_config = DataTranformationConfig(
            root_dir= config.root_dir,
            data_path= config.data_path
        )
        return data_transformation_config

# %%
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTranformation:
    def __init__(self, config: DataTranformationConfig):
        self.config= config

    def train_test_split(self):
        data= pd.read_csv(self.config.data_path)

        train, test= train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"), index =False)

        logger.info("Splited data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTranformation(config=data_transformation_config)
    data_transformation.train_test_split()
except Exception as e:
    raise e
# Out:
# [2026-03-22 18:09:44,093: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-03-22 18:09:44,096: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-03-22 18:09:44,101: INFO: common: yaml file: schema.yaml loaded successfully]
# [2026-03-22 18:09:44,104: INFO: common: created directory at: artifacts]
# [2026-03-22 18:09:44,106: INFO: common: created directory at: artifacts/data_transformation]
# [2026-03-22 18:09:44,255: INFO: 494479311: Splited data into training and test sets]
# [2026-03-22 18:09:44,258: INFO: 494479311: (1199, 12)]
# [2026-03-22 18:09:44,261: INFO: 494479311: (400, 12)]
# (1199, 12)
# (400, 12)
